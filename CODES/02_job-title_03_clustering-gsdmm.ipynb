# %% [markdown]
# ## Load libraries

# %%
# Libraries to work cross-platform
import os

# Libraries to work with dataset
import numpy as np
import pandas as pd
import ast                      # convert string to list after importing csv data
import tmtoolkit
import pickle

# Libraries to cluster data
from gsdmm import MovieGroupProcess

# Libraries to visualize data
# import matplotlib.pyplot as plt
import seaborn as sns
from cluster_visualization_helper import (
    visualize_cluster  # user-defined functions
)

# Libraries for evaluation
from sklearn import metrics

# Libraries for monitoring operation process
from tqdm import tqdm
from datetime import datetime
# from pprint import pprint
# import logging

# %% [markdown]
# ## Configurate and declare global variables

# %%
os_name = os.name

if os_name == 'nt':
    BASE_DIR = "E:/THIENDHB_GOOGLEDRIVE/MASTER TILBURG/THESIS/"
    INPUT_DIR = BASE_DIR + "DATASET/INPUT/"
    OUTPUT_DIR = BASE_DIR + "DATASET/OUTPUT/"
elif os_name == 'posix':
    BASE_DIR = "/media/pinkalinux/WORK/THIENDHB_GOOGLEDRIVE/MASTER TILBURG/THESIS/"
    INPUT_DIR = BASE_DIR + "DATASET/INPUT/"
    OUTPUT_DIR = BASE_DIR + "DATASET/OUTPUT/"

SEED = 6886

# %matplotlib inline

# %% [markdown]
# ## Import data

# %%
title_embeddings = np.load(OUTPUT_DIR + "title_embeddings.npy")

# %%
# title_embeddings.shape

# %%
title_docs = pd.read_csv(OUTPUT_DIR + "title_docs.csv")

# %%
title_docs["clean_job_title"] = title_docs["clean_job_title"].apply(ast.literal_eval)

# %% [markdown]
# ## Clustering data

# %% [markdown]
# ### Gibbs Sampling Dirichlet Mixture Model (GSDMM)

# %%
title_corpus = title_docs["clean_job_title"].values.tolist()
title_vocab = set(tmtoolkit.utils.flatten_list(title_corpus))
len(title_vocab), list(title_vocab)[:10]
# Out:
# (2617,
#  ['premium',
#   'replacement',
#   'registry',
#   'update',
#   'course',
#   'road',
#   'seg',
#   'introduce',
#   'speaker',
#   'landmine'])

# %%
def build_mgp_model(
    X,
    corpus,
    vocab_size,
    K=100,
    alpha=0.1,
    beta=0.1,
    n_iters=50,
    seed=6886,
):
    """
    A MovieGroupProcess is a conceptual model introduced by Yin and Wang 2014 to
    describe their Gibbs sampling algorithm for a Dirichlet Mixture Model for the
    clustering short text documents.
    Reference: http://dbgroup.cs.tsinghua.edu.cn/wangjy/papers/KDD14-GSDMM.pdf
    Imagine a professor is leading a film class. At the start of the class, the students
    are randomly assigned to K tables. Before class begins, the students make lists of
    their favorite films. The teacher reads the role n_iters times. When
    a student is called, the student must select a new table satisfying either:
        1) The new table has more students than the current table.
    OR
        2) The new table has students with similar lists of favorite movies.

    :param K: int
        Upper bound on the number of possible clusters. Typically many fewer
    :param alpha: float between 0 and 1
        Alpha controls the probability that a student will join a table that is currently empty
        When alpha is 0, no one will join an empty table.
    :param beta: float between 0 and 1
        Beta controls the student's affinity for other students with similar interests. A low beta means
        that students desire to sit with students of similar interests. A high beta means they are less
        concerned with affinity and are more influenced by the popularity of a table
    """

#     logging.debug("Start of GSDMM model for job titles")

    np.random.seed(SEED)
    mgp = MovieGroupProcess(K=K, alpha=alpha, beta=beta, n_iters=n_iters)

    """
        MovieGroupProcess().fit: Cluster the input documents
        :param docs: list of list
            list of lists containing the unique token set of each document
        :param V: total vocabulary size for each document
        :return: list of length len(doc)
            cluster label for each document
    """
    mgp_labels = mgp.fit(docs=corpus, vocab_size=vocab_size)

#     logging.debug("End of GSDMM model for job titles")

    return mgp, mgp_labels

# %%
# Define search parameters
k_range = [50, 100, 150]
alpha_range = [0.01, 0.25, 0.5, 0.75, 1.0]
beta_range = [0.01, 0.25, 0.5, 0.75, 1.0]
n_iter_range = [50, 100]
# k_range = [5]
# alpha_range = [0.5]
# beta_range = [0.5]
# n_iter_range = [5]

print(
    "Total hyperparameters in search space =",
    str(len(k_range) * len(alpha_range) * len(beta_range) * len(n_iter_range)),
)
# Out:
# Total hyperparameters in search space = 150

# %%
# # Set up logger for callback

# # Creating logger
# mylogs = logging.getLogger(__name__)
# mylogs.setLevel(logging.NOTSET)

# # Handler - log in file
# log_file = logging.FileHandler(OUTPUT_DIR + "title_gsdmm_model_callbacks.log")
# fileformat = logging.Formatter("%(asctime)s:%(levelname)s:%(message)s")
# log_file.setLevel(logging.NOTSET)
# log_file.setFormatter(fileformat)

# # Handler - log in console
# # stream = logging.StreamHandler()
# # streamformat = logging.Formatter("%(levelname)s:%(module)s:%(message)s")
# # stream.setLevel(logging.NOTSET)
# # stream.setFormatter(streamformat)

# # Adding all handlers to the logs
# mylogs.addHandler(log_file)
# # mylogs.addHandler(stream)
# print = mylogs.info

# %%
# # Set up logger for callback
# logging.basicConfig(
# #     filename=OUTPUT_DIR + "skills_lda_model_callbacks.log",
#     handlers=[
#         logging.FileHandler(
#             OUTPUT_DIR + "title_gsdmm_model_callbacks.log", "w", "utf-8"
#         )
#     ],
#     format="%(asctime)s:%(levelname)s:%(message)s",
#     level=logging.NOTSET,
# )

# Create empty list to store labels created by models
labels_list = []
model_list = []
duration_list = []
model_result = {"K": [], "alpha": [], "beta": [], "n_iters": [], "Silhouette": []}

start_loop_time = datetime.now()
print(f"Start loop {start_loop_time.strftime('%Y-%m-%d %H:%M:%S.%f')}")

# Loop through the search space
tqdm_bar = tqdm(
    desc="Tuning GSDMM model",
    total=len(k_range) * len(alpha_range) * len(beta_range) * len(n_iter_range),
)

for K in k_range:
    for alpha in alpha_range:
        for beta in beta_range:
            for n_iters in n_iter_range:
                print(f"K = {K}")
                print(f"alpha = {alpha}")
                print(f"beta = {beta}")
                print(f"n_iters = {n_iters}")

                starttime = datetime.now()
                print(f"Start {starttime.strftime('%Y-%m-%d %H:%M:%S.%f')}")

                mgp_model, mgp_labels = build_mgp_model(
                    X=title_docs,
                    corpus=title_corpus,
                    vocab_size=len(title_vocab),
                    K=K,
                    alpha=alpha,
                    beta=beta,
                    n_iters=n_iters,
                    seed=SEED,
                )

                endtime = datetime.now()
                print(f"End {endtime.strftime('%Y-%m-%d %H:%M:%S.%f')}")
                print(f"Duration {endtime - starttime}")

                duration_list.append(round((endtime - starttime).seconds / 60, 2))
                labels_list.append(mgp_labels)
                model_list.append(mgp_model)

                model_result["K"].append(K)
                model_result["alpha"].append(alpha)
                model_result["beta"].append(beta)
                model_result["n_iters"].append(n_iters)

                tqdm_bar.update(1)

tqdm_bar.close()

end_loop_time = datetime.now()
print(f"End loop {end_loop_time.strftime('%Y-%m-%d %H:%M:%S.%f')}")
print(f"Duration {end_loop_time - start_loop_time}")
# Out:
# Tuning GSDMM model:   0%|                                                                                       | 0/150 [00:00<?, ?it/s]
# Start loop 2021-05-04 02:27:01.723086
# K = 50
# alpha = 0.01
# beta = 0.01
# n_iters = 50
# Start 2021-05-04 02:27:01.762087
# In stage 0: transferred 17800 clusters with 50 clusters populated
# In stage 1: transferred 13725 clusters with 50 clusters populated
# In stage 2: transferred 9785 clusters with 50 clusters populated
# In stage 3: transferred 7733 clusters with 50 clusters populated
# In stage 4: transferred 6614 clusters with 50 clusters populated
# In stage 5: transferred 6051 clusters with 50 clusters populated
# In stage 6: transferred 5645 clusters with 50 clusters populated
# In stage 7: transferred 5502 clusters with 50 clusters populated
# In stage 8: transferred 5408 clusters with 50 clusters populated
# In stage 9: transferred 5341 clusters with 50 clusters populated
# In stage 10: transferred 5269 clusters with 50 clusters populated
# In stage 11: transferred 5126 clusters with 50 clusters populated
# In stage 12: transferred 5048 clusters with 50 clusters populated
# In stage 13: transferred 4941 clusters with 50 clusters populated
# In stage 14: transferred 4842 clusters with 50 clusters populated
# In stage 15: transferred 4903 clusters with 50 clusters populated
# In stage 16: transferred 4863 clusters with 50 clusters populated
# In stage 17: transferred 4843 clusters with 50 clusters populated
# In stage 18: transferred 4865 clusters with 50 clusters populated
# In stage 19: transferred 4848 clusters with 50 clusters populated
# In stage 20: transferred 4753 clusters with 50 clusters populated
# In stage 21: transferred 4670 clusters with 50 clusters populated
# In stage 22: transferred 4670 clusters with 50 clusters populated
# In stage 23: transferred 4600 clusters with 50 clusters populated
# In stage 24: transferred 4573 clusters with 50 clusters populated
# In stage 25: transferred 4524 clusters with 50 clusters populated
# In stage 26: transferred 4487 clusters with 50 clusters populated
# In stage 27: transferred 4439 clusters with 50 clusters populated
# In stage 28: transferred 4364 clusters with 50 clusters populated
# In stage 29: transferred 4386 clusters with 50 clusters populated
# In stage 30: transferred 4406 clusters with 50 clusters populated
# In stage 31: transferred 4503 clusters with 50 clusters populated
# In stage 32: transferred 4338 clusters with 50 clusters populated
# In stage 33: transferred 4456 clusters with 50 clusters populated
# In stage 34: transferred 4439 clusters with 50 clusters populated
# In stage 35: transferred 4386 clusters with 50 clusters populated
# In stage 36: transferred 4285 clusters with 50 clusters populated
# In stage 37: transferred 4337 clusters with 50 clusters populated
# In stage 38: transferred 4444 clusters with 50 clusters populated
# In stage 39: transferred 4483 clusters with 50 clusters populated
# In stage 40: transferred 4410 clusters with 50 clusters populated
# In stage 41: transferred 4400 clusters with 50 clusters populated
# In stage 42: transferred 4454 clusters with 50 clusters populated
# In stage 43: transferred 4393 clusters with 50 clusters populated
# In stage 44: transferred 4321 clusters with 50 clusters populated
# In stage 45: transferred 4302 clusters with 50 clusters populated
# In stage 46: transferred 4279 clusters with 50 clusters populated
# In stage 47: transferred 4202 clusters with 50 clusters populated
# In stage 48: transferred 4264 clusters with 50 clusters populated
# Tuning GSDMM model:   1%|▌                                                                          | 1/150 [10:37<26:24:14, 637.95s/it]
# In stage 49: transferred 4316 clusters with 50 clusters populated
# End 2021-05-04 02:37:39.707631
# Duration 0:10:37.945544
# K = 50
# alpha = 0.01
# beta = 0.01
# n_iters = 100
# Start 2021-05-04 02:37:39.708631
# In stage 0: transferred 17800 clusters with 50 clusters populated
# In stage 1: transferred 13725 clusters with 50 clusters populated
# In stage 2: transferred 9785 clusters with 50 clusters populated
# In stage 3: transferred 7733 clusters with 50 clusters populated
# In stage 4: transferred 6614 clusters with 50 clusters populated
# In stage 5: transferred 6051 clusters with 50 clusters populated
# In stage 6: transferred 5645 clusters with 50 clusters populated
# In stage 7: transferred 5502 clusters with 50 clusters populated
# In stage 8: transferred 5408 clusters with 50 clusters populated
# In stage 9: transferred 5341 clusters with 50 clusters populated
# In stage 10: transferred 5269 clusters with 50 clusters populated
# In stage 11: transferred 5126 clusters with 50 clusters populated
# In stage 12: transferred 5048 clusters with 50 clusters populated
# In stage 13: transferred 4941 clusters with 50 clusters populated
# In stage 14: transferred 4842 clusters with 50 clusters populated
# In stage 15: transferred 4903 clusters with 50 clusters populated
# In stage 16: transferred 4863 clusters with 50 clusters populated
# In stage 17: transferred 4843 clusters with 50 clusters populated
# In stage 18: transferred 4865 clusters with 50 clusters populated
# In stage 19: transferred 4848 clusters with 50 clusters populated
# In stage 20: transferred 4753 clusters with 50 clusters populated
# In stage 21: transferred 4670 clusters with 50 clusters populated
# In stage 22: transferred 4670 clusters with 50 clusters populated
# In stage 23: transferred 4600 clusters with 50 clusters populated
# In stage 24: transferred 4573 clusters with 50 clusters populated
# In stage 25: transferred 4524 clusters with 50 clusters populated
# In stage 26: transferred 4487 clusters with 50 clusters populated
# In stage 27: transferred 4439 clusters with 50 clusters populated
# In stage 28: transferred 4364 clusters with 50 clusters populated
# In stage 29: transferred 4386 clusters with 50 clusters populated
# In stage 30: transferred 4406 clusters with 50 clusters populated
# In stage 31: transferred 4503 clusters with 50 clusters populated
# In stage 32: transferred 4338 clusters with 50 clusters populated
# In stage 33: transferred 4456 clusters with 50 clusters populated
# In stage 34: transferred 4439 clusters with 50 clusters populated
# In stage 35: transferred 4386 clusters with 50 clusters populated
# In stage 36: transferred 4285 clusters with 50 clusters populated
# In stage 37: transferred 4337 clusters with 50 clusters populated
# In stage 38: transferred 4444 clusters with 50 clusters populated
# In stage 39: transferred 4483 clusters with 50 clusters populated
# In stage 40: transferred 4410 clusters with 50 clusters populated
# In stage 41: transferred 4400 clusters with 50 clusters populated
# In stage 42: transferred 4454 clusters with 50 clusters populated
# In stage 43: transferred 4393 clusters with 50 clusters populated
# In stage 44: transferred 4321 clusters with 50 clusters populated
# In stage 45: transferred 4302 clusters with 50 clusters populated
# In stage 46: transferred 4279 clusters with 50 clusters populated
# In stage 47: transferred 4202 clusters with 50 clusters populated
# In stage 48: transferred 4264 clusters with 50 clusters populated
# In stage 49: transferred 4316 clusters with 50 clusters populated
# In stage 50: transferred 4284 clusters with 50 clusters populated
# In stage 51: transferred 4331 clusters with 50 clusters populated
# In stage 52: transferred 4241 clusters with 50 clusters populated
# In stage 53: transferred 4310 clusters with 50 clusters populated
# In stage 54: transferred 4368 clusters with 50 clusters populated
# In stage 55: transferred 4336 clusters with 50 clusters populated
# In stage 56: transferred 4267 clusters with 50 clusters populated
# In stage 57: transferred 4348 clusters with 50 clusters populated
# In stage 58: transferred 4383 clusters with 50 clusters populated
# In stage 59: transferred 4233 clusters with 50 clusters populated
# In stage 60: transferred 4318 clusters with 50 clusters populated
# In stage 61: transferred 4308 clusters with 50 clusters populated
# In stage 62: transferred 4325 clusters with 50 clusters populated
# In stage 63: transferred 4309 clusters with 50 clusters populated
# In stage 64: transferred 4248 clusters with 50 clusters populated
# In stage 65: transferred 4157 clusters with 50 clusters populated
# In stage 66: transferred 4191 clusters with 50 clusters populated
# In stage 67: transferred 4325 clusters with 50 clusters populated
# In stage 68: transferred 4291 clusters with 50 clusters populated
# In stage 69: transferred 4178 clusters with 50 clusters populated
# In stage 70: transferred 4112 clusters with 50 clusters populated
# In stage 71: transferred 4106 clusters with 50 clusters populated
# In stage 72: transferred 4188 clusters with 50 clusters populated
# In stage 73: transferred 4142 clusters with 50 clusters populated
# In stage 74: transferred 4098 clusters with 50 clusters populated
# In stage 75: transferred 4177 clusters with 50 clusters populated
# In stage 76: transferred 4274 clusters with 50 clusters populated
# In stage 77: transferred 4179 clusters with 50 clusters populated
# In stage 78: transferred 4132 clusters with 50 clusters populated
# In stage 79: transferred 4206 clusters with 50 clusters populated
# In stage 80: transferred 4177 clusters with 50 clusters populated
# In stage 81: transferred 4234 clusters with 50 clusters populated
# In stage 82: transferred 4140 clusters with 50 clusters populated
# In stage 83: transferred 4154 clusters with 50 clusters populated
# In stage 84: transferred 4170 clusters with 50 clusters populated
# In stage 85: transferred 4132 clusters with 50 clusters populated
# In stage 86: transferred 4132 clusters with 50 clusters populated
# In stage 87: transferred 4142 clusters with 50 clusters populated
# In stage 88: transferred 4137 clusters with 50 clusters populated
# In stage 89: transferred 4139 clusters with 50 clusters populated
# In stage 90: transferred 4174 clusters with 50 clusters populated
# In stage 91: transferred 4154 clusters with 50 clusters populated
# In stage 92: transferred 4146 clusters with 50 clusters populated
# In stage 93: transferred 4119 clusters with 50 clusters populated
# In stage 94: transferred 4102 clusters with 50 clusters populated
# In stage 95: transferred 4025 clusters with 50 clusters populated
# In stage 96: transferred 4039 clusters with 50 clusters populated
# In stage 97: transferred 4006 clusters with 50 clusters populated
# In stage 98: transferred 3990 clusters with 50 clusters populated
# Tuning GSDMM model:   1%|█                                                                          | 2/150 [30:31<39:40:17, 964.98s/it]
# In stage 99: transferred 4122 clusters with 50 clusters populated
# End 2021-05-04 02:57:33.616145
# Duration 0:19:53.907514
# K = 50
# alpha = 0.01
# beta = 0.25
# n_iters = 50
# Start 2021-05-04 02:57:33.618143
# In stage 0: transferred 18271 clusters with 50 clusters populated
# In stage 1: transferred 14886 clusters with 50 clusters populated
# In stage 2: transferred 10067 clusters with 50 clusters populated
# In stage 3: transferred 7407 clusters with 50 clusters populated
# In stage 4: transferred 6059 clusters with 49 clusters populated
# In stage 5: transferred 5341 clusters with 46 clusters populated
# In stage 6: transferred 4925 clusters with 44 clusters populated
# In stage 7: transferred 4893 clusters with 42 clusters populated
# In stage 8: transferred 4577 clusters with 39 clusters populated
# In stage 9: transferred 4597 clusters with 38 clusters populated
# In stage 10: transferred 4439 clusters with 38 clusters populated
# In stage 11: transferred 4450 clusters with 36 clusters populated
# In stage 12: transferred 4364 clusters with 34 clusters populated
# In stage 13: transferred 4243 clusters with 34 clusters populated
# In stage 14: transferred 4087 clusters with 35 clusters populated
# In stage 15: transferred 4019 clusters with 33 clusters populated
# In stage 16: transferred 3996 clusters with 32 clusters populated
# In stage 17: transferred 3966 clusters with 31 clusters populated
# In stage 18: transferred 3891 clusters with 31 clusters populated
# In stage 19: transferred 3982 clusters with 31 clusters populated
# In stage 20: transferred 3915 clusters with 31 clusters populated
# In stage 21: transferred 3868 clusters with 31 clusters populated
# In stage 22: transferred 3861 clusters with 31 clusters populated
# In stage 23: transferred 3931 clusters with 30 clusters populated
# In stage 24: transferred 3889 clusters with 30 clusters populated
# In stage 25: transferred 3917 clusters with 30 clusters populated
# In stage 26: transferred 3936 clusters with 30 clusters populated
# In stage 27: transferred 3962 clusters with 30 clusters populated
# In stage 28: transferred 3847 clusters with 30 clusters populated
# In stage 29: transferred 3823 clusters with 30 clusters populated
# In stage 30: transferred 3842 clusters with 30 clusters populated
# In stage 31: transferred 3943 clusters with 30 clusters populated
# In stage 32: transferred 3948 clusters with 29 clusters populated
# In stage 33: transferred 3959 clusters with 29 clusters populated
# In stage 34: transferred 3876 clusters with 28 clusters populated
# In stage 35: transferred 3898 clusters with 28 clusters populated
# In stage 36: transferred 3868 clusters with 28 clusters populated
# In stage 37: transferred 3860 clusters with 28 clusters populated
# In stage 38: transferred 3897 clusters with 28 clusters populated
# In stage 39: transferred 3823 clusters with 28 clusters populated
# In stage 40: transferred 3879 clusters with 28 clusters populated
# In stage 41: transferred 3855 clusters with 28 clusters populated
# In stage 42: transferred 3919 clusters with 28 clusters populated
# In stage 43: transferred 3861 clusters with 28 clusters populated
# In stage 44: transferred 3828 clusters with 28 clusters populated
# In stage 45: transferred 3807 clusters with 28 clusters populated
# In stage 46: transferred 3874 clusters with 28 clusters populated
# In stage 47: transferred 3815 clusters with 28 clusters populated
# In stage 48: transferred 3820 clusters with 28 clusters populated
# Tuning GSDMM model:   2%|█▌                                                                         | 3/150 [40:24<32:27:42, 794.98s/it]
# In stage 49: transferred 3868 clusters with 28 clusters populated
# End 2021-05-04 03:07:26.299345
# Duration 0:09:52.681202
# K = 50
# alpha = 0.01
# beta = 0.25
# n_iters = 100
# Start 2021-05-04 03:07:26.300308
# In stage 0: transferred 18271 clusters with 50 clusters populated
# In stage 1: transferred 14886 clusters with 50 clusters populated
# In stage 2: transferred 10067 clusters with 50 clusters populated
# In stage 3: transferred 7407 clusters with 50 clusters populated
# In stage 4: transferred 6059 clusters with 49 clusters populated
# In stage 5: transferred 5341 clusters with 46 clusters populated
# In stage 6: transferred 4925 clusters with 44 clusters populated
# In stage 7: transferred 4893 clusters with 42 clusters populated
# In stage 8: transferred 4577 clusters with 39 clusters populated
# In stage 9: transferred 4597 clusters with 38 clusters populated
# In stage 10: transferred 4439 clusters with 38 clusters populated
# In stage 11: transferred 4450 clusters with 36 clusters populated
# In stage 12: transferred 4364 clusters with 34 clusters populated
# In stage 13: transferred 4243 clusters with 34 clusters populated
# In stage 14: transferred 4087 clusters with 35 clusters populated
# In stage 15: transferred 4019 clusters with 33 clusters populated
# In stage 16: transferred 3996 clusters with 32 clusters populated
# In stage 17: transferred 3966 clusters with 31 clusters populated
# In stage 18: transferred 3891 clusters with 31 clusters populated
# In stage 19: transferred 3982 clusters with 31 clusters populated
# In stage 20: transferred 3915 clusters with 31 clusters populated
# In stage 21: transferred 3868 clusters with 31 clusters populated
# In stage 22: transferred 3861 clusters with 31 clusters populated
# In stage 23: transferred 3931 clusters with 30 clusters populated
# In stage 24: transferred 3889 clusters with 30 clusters populated
# In stage 25: transferred 3917 clusters with 30 clusters populated
# In stage 26: transferred 3936 clusters with 30 clusters populated
# In stage 27: transferred 3962 clusters with 30 clusters populated
# In stage 28: transferred 3847 clusters with 30 clusters populated
# In stage 29: transferred 3823 clusters with 30 clusters populated
# In stage 30: transferred 3842 clusters with 30 clusters populated
# In stage 31: transferred 3943 clusters with 30 clusters populated
# In stage 32: transferred 3948 clusters with 29 clusters populated
# In stage 33: transferred 3959 clusters with 29 clusters populated
# In stage 34: transferred 3876 clusters with 28 clusters populated
# In stage 35: transferred 3898 clusters with 28 clusters populated
# In stage 36: transferred 3868 clusters with 28 clusters populated
# In stage 37: transferred 3860 clusters with 28 clusters populated
# In stage 38: transferred 3897 clusters with 28 clusters populated
# In stage 39: transferred 3823 clusters with 28 clusters populated
# In stage 40: transferred 3879 clusters with 28 clusters populated
# In stage 41: transferred 3855 clusters with 28 clusters populated
# In stage 42: transferred 3919 clusters with 28 clusters populated
# In stage 43: transferred 3861 clusters with 28 clusters populated
# In stage 44: transferred 3828 clusters with 28 clusters populated
# In stage 45: transferred 3807 clusters with 28 clusters populated
# In stage 46: transferred 3874 clusters with 28 clusters populated
# In stage 47: transferred 3815 clusters with 28 clusters populated
# In stage 48: transferred 3820 clusters with 28 clusters populated
# In stage 49: transferred 3868 clusters with 28 clusters populated
# In stage 50: transferred 3852 clusters with 28 clusters populated
# In stage 51: transferred 3890 clusters with 28 clusters populated
# In stage 52: transferred 3883 clusters with 27 clusters populated
# In stage 53: transferred 3797 clusters with 28 clusters populated
# In stage 54: transferred 3863 clusters with 27 clusters populated
# In stage 55: transferred 3893 clusters with 27 clusters populated
# In stage 56: transferred 3819 clusters with 26 clusters populated
# In stage 57: transferred 3834 clusters with 26 clusters populated
# In stage 58: transferred 3945 clusters with 26 clusters populated
# In stage 59: transferred 3924 clusters with 26 clusters populated
# In stage 60: transferred 3872 clusters with 27 clusters populated
# In stage 61: transferred 3828 clusters with 26 clusters populated
# In stage 62: transferred 3827 clusters with 25 clusters populated
# In stage 63: transferred 3807 clusters with 25 clusters populated
# In stage 64: transferred 3818 clusters with 25 clusters populated
# In stage 65: transferred 3733 clusters with 25 clusters populated
# In stage 66: transferred 3750 clusters with 25 clusters populated
# In stage 67: transferred 3715 clusters with 25 clusters populated
# In stage 68: transferred 3808 clusters with 25 clusters populated
# In stage 69: transferred 3693 clusters with 25 clusters populated
# In stage 70: transferred 3754 clusters with 25 clusters populated
# In stage 71: transferred 3716 clusters with 25 clusters populated
# In stage 72: transferred 3742 clusters with 25 clusters populated
# In stage 73: transferred 3865 clusters with 25 clusters populated
# In stage 74: transferred 3890 clusters with 25 clusters populated
# In stage 75: transferred 3876 clusters with 26 clusters populated
# In stage 76: transferred 3801 clusters with 25 clusters populated
# In stage 77: transferred 3728 clusters with 25 clusters populated
# In stage 78: transferred 3787 clusters with 25 clusters populated
# In stage 79: transferred 3771 clusters with 25 clusters populated
# In stage 80: transferred 3755 clusters with 25 clusters populated
# In stage 81: transferred 3892 clusters with 25 clusters populated
# In stage 82: transferred 3859 clusters with 25 clusters populated
# In stage 83: transferred 3794 clusters with 25 clusters populated
# In stage 84: transferred 3716 clusters with 25 clusters populated
# In stage 85: transferred 3708 clusters with 25 clusters populated
# In stage 86: transferred 3757 clusters with 25 clusters populated
# In stage 87: transferred 3819 clusters with 25 clusters populated
# In stage 88: transferred 3852 clusters with 25 clusters populated
# In stage 89: transferred 3862 clusters with 25 clusters populated
# In stage 90: transferred 3808 clusters with 26 clusters populated
# In stage 91: transferred 3774 clusters with 25 clusters populated
# In stage 92: transferred 3786 clusters with 25 clusters populated
# In stage 93: transferred 3746 clusters with 25 clusters populated
# In stage 94: transferred 3706 clusters with 25 clusters populated
# In stage 95: transferred 3677 clusters with 25 clusters populated
# In stage 96: transferred 3739 clusters with 25 clusters populated
# In stage 97: transferred 3633 clusters with 25 clusters populated
# Tuning GSDMM model:   3%|██                                                                         | 4/150 [58:58<37:20:51, 920.90s/it]
# In stage 98: transferred 3681 clusters with 25 clusters populated
# In stage 99: transferred 3677 clusters with 25 clusters populated
# End 2021-05-04 03:26:00.239927
# Duration 0:18:33.939619
# K = 50
# alpha = 0.01
# beta = 0.5
# n_iters = 50
# Start 2021-05-04 03:26:00.241929
# In stage 0: transferred 18362 clusters with 50 clusters populated
# In stage 1: transferred 15056 clusters with 50 clusters populated
# In stage 2: transferred 9965 clusters with 50 clusters populated
# In stage 3: transferred 7100 clusters with 38 clusters populated
# In stage 4: transferred 5756 clusters with 27 clusters populated
# In stage 5: transferred 5125 clusters with 24 clusters populated
# In stage 6: transferred 4669 clusters with 22 clusters populated
# In stage 7: transferred 4484 clusters with 21 clusters populated
# In stage 8: transferred 4192 clusters with 18 clusters populated
# In stage 9: transferred 4064 clusters with 18 clusters populated
# In stage 10: transferred 3954 clusters with 17 clusters populated
# In stage 11: transferred 3850 clusters with 17 clusters populated
# In stage 12: transferred 3660 clusters with 17 clusters populated
# In stage 13: transferred 3541 clusters with 18 clusters populated
# In stage 14: transferred 3546 clusters with 16 clusters populated
# In stage 15: transferred 3560 clusters with 16 clusters populated
# In stage 16: transferred 3540 clusters with 16 clusters populated
# In stage 17: transferred 3557 clusters with 15 clusters populated
# In stage 18: transferred 3474 clusters with 15 clusters populated
# In stage 19: transferred 3595 clusters with 15 clusters populated
# In stage 20: transferred 3533 clusters with 14 clusters populated
# In stage 21: transferred 3466 clusters with 14 clusters populated
# In stage 22: transferred 3531 clusters with 14 clusters populated
# In stage 23: transferred 3514 clusters with 13 clusters populated
# In stage 24: transferred 3482 clusters with 13 clusters populated
# In stage 25: transferred 3414 clusters with 13 clusters populated
# In stage 26: transferred 3410 clusters with 13 clusters populated
# In stage 27: transferred 3452 clusters with 13 clusters populated
# In stage 28: transferred 3470 clusters with 13 clusters populated
# In stage 29: transferred 3488 clusters with 13 clusters populated
# In stage 30: transferred 3469 clusters with 13 clusters populated
# In stage 31: transferred 3441 clusters with 13 clusters populated
# In stage 32: transferred 3400 clusters with 13 clusters populated
# In stage 33: transferred 3548 clusters with 14 clusters populated
# In stage 34: transferred 3467 clusters with 13 clusters populated
# In stage 35: transferred 3532 clusters with 13 clusters populated
# In stage 36: transferred 3556 clusters with 13 clusters populated
# In stage 37: transferred 3518 clusters with 13 clusters populated
# In stage 38: transferred 3432 clusters with 14 clusters populated
# In stage 39: transferred 3359 clusters with 13 clusters populated
# In stage 40: transferred 3331 clusters with 13 clusters populated
# In stage 41: transferred 3447 clusters with 13 clusters populated
# In stage 42: transferred 3498 clusters with 13 clusters populated
# In stage 43: transferred 3485 clusters with 14 clusters populated
# In stage 44: transferred 3502 clusters with 13 clusters populated
# In stage 45: transferred 3422 clusters with 13 clusters populated
# In stage 46: transferred 3297 clusters with 13 clusters populated
# In stage 47: transferred 3347 clusters with 13 clusters populated
# In stage 48: transferred 3303 clusters with 13 clusters populated
# Tuning GSDMM model:   3%|██▍                                                                      | 5/150 [1:06:06<29:55:48, 743.09s/it]
# In stage 49: transferred 3391 clusters with 14 clusters populated
# End 2021-05-04 03:33:08.061177
# Duration 0:07:07.819248
# K = 50
# alpha = 0.01
# beta = 0.5
# n_iters = 100
# Start 2021-05-04 03:33:08.063156
# In stage 0: transferred 18362 clusters with 50 clusters populated
# In stage 1: transferred 15056 clusters with 50 clusters populated
# In stage 2: transferred 9965 clusters with 50 clusters populated
# In stage 3: transferred 7100 clusters with 38 clusters populated
# In stage 4: transferred 5756 clusters with 27 clusters populated
# In stage 5: transferred 5125 clusters with 24 clusters populated
# In stage 6: transferred 4669 clusters with 22 clusters populated
# In stage 7: transferred 4484 clusters with 21 clusters populated
# In stage 8: transferred 4192 clusters with 18 clusters populated
# In stage 9: transferred 4064 clusters with 18 clusters populated
# In stage 10: transferred 3954 clusters with 17 clusters populated
# In stage 11: transferred 3850 clusters with 17 clusters populated
# In stage 12: transferred 3660 clusters with 17 clusters populated
# In stage 13: transferred 3541 clusters with 18 clusters populated
# In stage 14: transferred 3546 clusters with 16 clusters populated
# In stage 15: transferred 3560 clusters with 16 clusters populated
# In stage 16: transferred 3540 clusters with 16 clusters populated
# In stage 17: transferred 3557 clusters with 15 clusters populated
# In stage 18: transferred 3474 clusters with 15 clusters populated
# In stage 19: transferred 3595 clusters with 15 clusters populated
# In stage 20: transferred 3533 clusters with 14 clusters populated
# In stage 21: transferred 3466 clusters with 14 clusters populated
# In stage 22: transferred 3531 clusters with 14 clusters populated
# In stage 23: transferred 3514 clusters with 13 clusters populated
# In stage 24: transferred 3482 clusters with 13 clusters populated
# In stage 25: transferred 3414 clusters with 13 clusters populated
# In stage 26: transferred 3410 clusters with 13 clusters populated
# In stage 27: transferred 3452 clusters with 13 clusters populated
# In stage 28: transferred 3470 clusters with 13 clusters populated
# In stage 29: transferred 3488 clusters with 13 clusters populated
# In stage 30: transferred 3469 clusters with 13 clusters populated
# In stage 31: transferred 3441 clusters with 13 clusters populated
# In stage 32: transferred 3400 clusters with 13 clusters populated
# In stage 33: transferred 3548 clusters with 14 clusters populated
# In stage 34: transferred 3467 clusters with 13 clusters populated
# In stage 35: transferred 3532 clusters with 13 clusters populated
# In stage 36: transferred 3556 clusters with 13 clusters populated
# In stage 37: transferred 3518 clusters with 13 clusters populated
# In stage 38: transferred 3432 clusters with 14 clusters populated
# In stage 39: transferred 3359 clusters with 13 clusters populated
# In stage 40: transferred 3331 clusters with 13 clusters populated
# In stage 41: transferred 3447 clusters with 13 clusters populated
# In stage 42: transferred 3498 clusters with 13 clusters populated
# In stage 43: transferred 3485 clusters with 14 clusters populated
# In stage 44: transferred 3502 clusters with 13 clusters populated
# In stage 45: transferred 3422 clusters with 13 clusters populated
# In stage 46: transferred 3297 clusters with 13 clusters populated
# In stage 47: transferred 3347 clusters with 13 clusters populated
# In stage 48: transferred 3303 clusters with 13 clusters populated
# In stage 49: transferred 3391 clusters with 14 clusters populated
# In stage 50: transferred 3350 clusters with 14 clusters populated
# In stage 51: transferred 3414 clusters with 13 clusters populated
# In stage 52: transferred 3470 clusters with 13 clusters populated
# In stage 53: transferred 3498 clusters with 13 clusters populated
# In stage 54: transferred 3491 clusters with 13 clusters populated
# In stage 55: transferred 3441 clusters with 13 clusters populated
# In stage 56: transferred 3443 clusters with 13 clusters populated
# In stage 57: transferred 3370 clusters with 13 clusters populated
# In stage 58: transferred 3452 clusters with 13 clusters populated
# In stage 59: transferred 3494 clusters with 13 clusters populated
# In stage 60: transferred 3363 clusters with 13 clusters populated
# In stage 61: transferred 3403 clusters with 13 clusters populated
# In stage 62: transferred 3495 clusters with 13 clusters populated
# In stage 63: transferred 3412 clusters with 13 clusters populated
# In stage 64: transferred 3339 clusters with 13 clusters populated
# In stage 65: transferred 3379 clusters with 13 clusters populated
# In stage 66: transferred 3453 clusters with 13 clusters populated
# In stage 67: transferred 3400 clusters with 13 clusters populated
# In stage 68: transferred 3397 clusters with 13 clusters populated
# In stage 69: transferred 3359 clusters with 13 clusters populated
# In stage 70: transferred 3387 clusters with 13 clusters populated
# In stage 71: transferred 3411 clusters with 13 clusters populated
# In stage 72: transferred 3373 clusters with 13 clusters populated
# In stage 73: transferred 3396 clusters with 13 clusters populated
# In stage 74: transferred 3424 clusters with 13 clusters populated
# In stage 75: transferred 3421 clusters with 13 clusters populated
# In stage 76: transferred 3442 clusters with 13 clusters populated
# In stage 77: transferred 3396 clusters with 13 clusters populated
# In stage 78: transferred 3490 clusters with 13 clusters populated
# In stage 79: transferred 3469 clusters with 13 clusters populated
# In stage 80: transferred 3389 clusters with 13 clusters populated
# In stage 81: transferred 3417 clusters with 13 clusters populated
# In stage 82: transferred 3424 clusters with 13 clusters populated
# In stage 83: transferred 3465 clusters with 13 clusters populated
# In stage 84: transferred 3467 clusters with 13 clusters populated
# In stage 85: transferred 3435 clusters with 13 clusters populated
# In stage 86: transferred 3411 clusters with 13 clusters populated
# In stage 87: transferred 3416 clusters with 13 clusters populated
# In stage 88: transferred 3402 clusters with 13 clusters populated
# In stage 89: transferred 3419 clusters with 13 clusters populated
# In stage 90: transferred 3428 clusters with 13 clusters populated
# In stage 91: transferred 3497 clusters with 13 clusters populated
# In stage 92: transferred 3496 clusters with 13 clusters populated
# In stage 93: transferred 3482 clusters with 13 clusters populated
# In stage 94: transferred 3396 clusters with 13 clusters populated
# In stage 95: transferred 3470 clusters with 13 clusters populated
# In stage 96: transferred 3457 clusters with 13 clusters populated
# In stage 97: transferred 3446 clusters with 13 clusters populated
# In stage 98: transferred 3346 clusters with 13 clusters populated
# Tuning GSDMM model:   4%|██▉                                                                      | 6/150 [1:19:45<30:45:20, 768.89s/it]
# In stage 99: transferred 3437 clusters with 13 clusters populated
# End 2021-05-04 03:46:47.030554
# Duration 0:13:38.967398
# K = 50
# alpha = 0.01
# beta = 0.75
# n_iters = 50
# Start 2021-05-04 03:46:47.032552
# In stage 0: transferred 18453 clusters with 50 clusters populated
# In stage 1: transferred 14939 clusters with 50 clusters populated
# In stage 2: transferred 8148 clusters with 47 clusters populated
# In stage 3: transferred 5030 clusters with 32 clusters populated
# In stage 4: transferred 3985 clusters with 17 clusters populated
# In stage 5: transferred 3612 clusters with 15 clusters populated
# In stage 6: transferred 3255 clusters with 15 clusters populated
# In stage 7: transferred 3191 clusters with 14 clusters populated
# In stage 8: transferred 3199 clusters with 13 clusters populated
# In stage 9: transferred 3146 clusters with 13 clusters populated
# In stage 10: transferred 3096 clusters with 13 clusters populated
# In stage 11: transferred 3114 clusters with 13 clusters populated
# In stage 12: transferred 3013 clusters with 13 clusters populated
# In stage 13: transferred 3050 clusters with 13 clusters populated
# In stage 14: transferred 3025 clusters with 13 clusters populated
# In stage 15: transferred 3083 clusters with 12 clusters populated
# In stage 16: transferred 3063 clusters with 12 clusters populated
# In stage 17: transferred 2992 clusters with 12 clusters populated
# In stage 18: transferred 2994 clusters with 12 clusters populated
# In stage 19: transferred 3000 clusters with 11 clusters populated
# In stage 20: transferred 3003 clusters with 12 clusters populated
# In stage 21: transferred 3083 clusters with 11 clusters populated
# In stage 22: transferred 3002 clusters with 11 clusters populated
# In stage 23: transferred 2992 clusters with 11 clusters populated
# In stage 24: transferred 2964 clusters with 12 clusters populated
# In stage 25: transferred 2984 clusters with 11 clusters populated
# In stage 26: transferred 3013 clusters with 11 clusters populated
# In stage 27: transferred 3025 clusters with 10 clusters populated
# In stage 28: transferred 2931 clusters with 10 clusters populated
# In stage 29: transferred 2903 clusters with 10 clusters populated
# In stage 30: transferred 3029 clusters with 10 clusters populated
# In stage 31: transferred 3003 clusters with 10 clusters populated
# In stage 32: transferred 2962 clusters with 10 clusters populated
# In stage 33: transferred 3008 clusters with 11 clusters populated
# In stage 34: transferred 3003 clusters with 10 clusters populated
# In stage 35: transferred 3009 clusters with 10 clusters populated
# In stage 36: transferred 2997 clusters with 10 clusters populated
# In stage 37: transferred 3012 clusters with 10 clusters populated
# In stage 38: transferred 2976 clusters with 10 clusters populated
# In stage 39: transferred 2906 clusters with 10 clusters populated
# In stage 40: transferred 2900 clusters with 10 clusters populated
# In stage 41: transferred 2838 clusters with 10 clusters populated
# In stage 42: transferred 2783 clusters with 10 clusters populated
# In stage 43: transferred 2885 clusters with 10 clusters populated
# In stage 44: transferred 2920 clusters with 10 clusters populated
# In stage 45: transferred 2952 clusters with 10 clusters populated
# In stage 46: transferred 2877 clusters with 10 clusters populated
# In stage 47: transferred 2846 clusters with 10 clusters populated
# In stage 48: transferred 2847 clusters with 10 clusters populated
# Tuning GSDMM model:   5%|███▍                                                                     | 7/150 [1:26:32<25:51:06, 650.81s/it]
# In stage 49: transferred 2821 clusters with 10 clusters populated
# End 2021-05-04 03:53:34.734788
# Duration 0:06:47.702236
# K = 50
# alpha = 0.01
# beta = 0.75
# n_iters = 100
# Start 2021-05-04 03:53:34.735827
# In stage 0: transferred 18453 clusters with 50 clusters populated
# In stage 1: transferred 14939 clusters with 50 clusters populated
# In stage 2: transferred 8148 clusters with 47 clusters populated
# In stage 3: transferred 5030 clusters with 32 clusters populated
# In stage 4: transferred 3985 clusters with 17 clusters populated
# In stage 5: transferred 3612 clusters with 15 clusters populated
# In stage 6: transferred 3255 clusters with 15 clusters populated
# In stage 7: transferred 3191 clusters with 14 clusters populated
# In stage 8: transferred 3199 clusters with 13 clusters populated
# In stage 9: transferred 3146 clusters with 13 clusters populated
# In stage 10: transferred 3096 clusters with 13 clusters populated
# In stage 11: transferred 3114 clusters with 13 clusters populated
# In stage 12: transferred 3013 clusters with 13 clusters populated
# In stage 13: transferred 3050 clusters with 13 clusters populated
# In stage 14: transferred 3025 clusters with 13 clusters populated
# In stage 15: transferred 3083 clusters with 12 clusters populated
# In stage 16: transferred 3063 clusters with 12 clusters populated
# In stage 17: transferred 2992 clusters with 12 clusters populated
# In stage 18: transferred 2994 clusters with 12 clusters populated
# In stage 19: transferred 3000 clusters with 11 clusters populated
# In stage 20: transferred 3003 clusters with 12 clusters populated
# In stage 21: transferred 3083 clusters with 11 clusters populated
# In stage 22: transferred 3002 clusters with 11 clusters populated
# In stage 23: transferred 2992 clusters with 11 clusters populated
# In stage 24: transferred 2964 clusters with 12 clusters populated
# In stage 25: transferred 2984 clusters with 11 clusters populated
# In stage 26: transferred 3013 clusters with 11 clusters populated
# In stage 27: transferred 3025 clusters with 10 clusters populated
# In stage 28: transferred 2931 clusters with 10 clusters populated
# In stage 29: transferred 2903 clusters with 10 clusters populated
# In stage 30: transferred 3029 clusters with 10 clusters populated
# In stage 31: transferred 3003 clusters with 10 clusters populated
# In stage 32: transferred 2962 clusters with 10 clusters populated
# In stage 33: transferred 3008 clusters with 11 clusters populated
# In stage 34: transferred 3003 clusters with 10 clusters populated
# In stage 35: transferred 3009 clusters with 10 clusters populated
# In stage 36: transferred 2997 clusters with 10 clusters populated
# In stage 37: transferred 3012 clusters with 10 clusters populated
# In stage 38: transferred 2976 clusters with 10 clusters populated
# In stage 39: transferred 2906 clusters with 10 clusters populated
# In stage 40: transferred 2900 clusters with 10 clusters populated
# In stage 41: transferred 2838 clusters with 10 clusters populated
# In stage 42: transferred 2783 clusters with 10 clusters populated
# In stage 43: transferred 2885 clusters with 10 clusters populated
# In stage 44: transferred 2920 clusters with 10 clusters populated
# In stage 45: transferred 2952 clusters with 10 clusters populated
# In stage 46: transferred 2877 clusters with 10 clusters populated
# In stage 47: transferred 2846 clusters with 10 clusters populated
# In stage 48: transferred 2847 clusters with 10 clusters populated
# In stage 49: transferred 2821 clusters with 10 clusters populated
# In stage 50: transferred 2863 clusters with 10 clusters populated
# In stage 51: transferred 2930 clusters with 10 clusters populated
# In stage 52: transferred 2888 clusters with 10 clusters populated
# In stage 53: transferred 2873 clusters with 10 clusters populated
# In stage 54: transferred 2905 clusters with 10 clusters populated
# In stage 55: transferred 2961 clusters with 10 clusters populated
# In stage 56: transferred 2969 clusters with 10 clusters populated
# In stage 57: transferred 2961 clusters with 10 clusters populated
# In stage 58: transferred 2903 clusters with 10 clusters populated
# In stage 59: transferred 2994 clusters with 10 clusters populated
# In stage 60: transferred 2965 clusters with 10 clusters populated
# In stage 61: transferred 2954 clusters with 10 clusters populated
# In stage 62: transferred 2956 clusters with 10 clusters populated
# In stage 63: transferred 2960 clusters with 10 clusters populated
# In stage 64: transferred 2945 clusters with 10 clusters populated
# In stage 65: transferred 2930 clusters with 10 clusters populated
# In stage 66: transferred 3013 clusters with 10 clusters populated
# In stage 67: transferred 3089 clusters with 10 clusters populated
# In stage 68: transferred 2991 clusters with 10 clusters populated
# In stage 69: transferred 3111 clusters with 10 clusters populated
# In stage 70: transferred 3008 clusters with 10 clusters populated
# In stage 71: transferred 2912 clusters with 10 clusters populated
# In stage 72: transferred 3068 clusters with 10 clusters populated
# In stage 73: transferred 3058 clusters with 10 clusters populated
# In stage 74: transferred 3164 clusters with 10 clusters populated
# In stage 75: transferred 3176 clusters with 10 clusters populated
# In stage 76: transferred 3154 clusters with 10 clusters populated
# In stage 77: transferred 3150 clusters with 10 clusters populated
# In stage 78: transferred 2994 clusters with 10 clusters populated
# In stage 79: transferred 2906 clusters with 10 clusters populated
# In stage 80: transferred 2961 clusters with 10 clusters populated
# In stage 81: transferred 3003 clusters with 10 clusters populated
# In stage 82: transferred 2990 clusters with 10 clusters populated
# In stage 83: transferred 3020 clusters with 10 clusters populated
# In stage 84: transferred 3076 clusters with 9 clusters populated
# In stage 85: transferred 2989 clusters with 9 clusters populated
# In stage 86: transferred 3097 clusters with 9 clusters populated
# In stage 87: transferred 3067 clusters with 9 clusters populated
# In stage 88: transferred 3053 clusters with 9 clusters populated
# In stage 89: transferred 3013 clusters with 9 clusters populated
# In stage 90: transferred 2973 clusters with 9 clusters populated
# In stage 91: transferred 2989 clusters with 9 clusters populated
# In stage 92: transferred 2993 clusters with 9 clusters populated
# In stage 93: transferred 2937 clusters with 9 clusters populated
# In stage 94: transferred 2976 clusters with 9 clusters populated
# In stage 95: transferred 2996 clusters with 9 clusters populated
# In stage 96: transferred 2951 clusters with 9 clusters populated
# In stage 97: transferred 3016 clusters with 9 clusters populated
# In stage 98: transferred 3013 clusters with 9 clusters populated
# Tuning GSDMM model:   5%|███▉                                                                     | 8/150 [1:40:04<27:41:07, 701.89s/it]
# In stage 99: transferred 3001 clusters with 9 clusters populated
# End 2021-05-04 04:07:05.979163
# Duration 0:13:31.243336
# K = 50
# alpha = 0.01
# beta = 1.0
# n_iters = 50
# Start 2021-05-04 04:07:05.980210
# In stage 0: transferred 18451 clusters with 50 clusters populated
# In stage 1: transferred 15369 clusters with 50 clusters populated
# In stage 2: transferred 8549 clusters with 47 clusters populated
# In stage 3: transferred 5339 clusters with 29 clusters populated
# In stage 4: transferred 4252 clusters with 17 clusters populated
# In stage 5: transferred 3795 clusters with 14 clusters populated
# In stage 6: transferred 3563 clusters with 13 clusters populated
# In stage 7: transferred 3362 clusters with 9 clusters populated
# In stage 8: transferred 3292 clusters with 9 clusters populated
# In stage 9: transferred 3188 clusters with 9 clusters populated
# In stage 10: transferred 3125 clusters with 9 clusters populated
# In stage 11: transferred 3025 clusters with 9 clusters populated
# In stage 12: transferred 3051 clusters with 9 clusters populated
# In stage 13: transferred 3026 clusters with 10 clusters populated
# In stage 14: transferred 2937 clusters with 9 clusters populated
# In stage 15: transferred 2952 clusters with 9 clusters populated
# In stage 16: transferred 2905 clusters with 9 clusters populated
# In stage 17: transferred 2920 clusters with 9 clusters populated
# In stage 18: transferred 2941 clusters with 9 clusters populated
# In stage 19: transferred 2899 clusters with 9 clusters populated
# In stage 20: transferred 2882 clusters with 9 clusters populated
# In stage 21: transferred 2929 clusters with 9 clusters populated
# In stage 22: transferred 2818 clusters with 8 clusters populated
# In stage 23: transferred 2825 clusters with 8 clusters populated
# In stage 24: transferred 2826 clusters with 8 clusters populated
# In stage 25: transferred 2783 clusters with 8 clusters populated
# In stage 26: transferred 2778 clusters with 8 clusters populated
# In stage 27: transferred 2753 clusters with 7 clusters populated
# In stage 28: transferred 2750 clusters with 7 clusters populated
# In stage 29: transferred 2776 clusters with 7 clusters populated
# In stage 30: transferred 2721 clusters with 7 clusters populated
# In stage 31: transferred 2714 clusters with 7 clusters populated
# In stage 32: transferred 2586 clusters with 7 clusters populated
# In stage 33: transferred 2419 clusters with 7 clusters populated
# In stage 34: transferred 2268 clusters with 7 clusters populated
# In stage 35: transferred 2235 clusters with 7 clusters populated
# In stage 36: transferred 2295 clusters with 7 clusters populated
# In stage 37: transferred 2295 clusters with 8 clusters populated
# In stage 38: transferred 2258 clusters with 8 clusters populated
# In stage 39: transferred 2231 clusters with 7 clusters populated
# In stage 40: transferred 2233 clusters with 7 clusters populated
# In stage 41: transferred 2214 clusters with 7 clusters populated
# In stage 42: transferred 2223 clusters with 7 clusters populated
# In stage 43: transferred 2236 clusters with 7 clusters populated
# In stage 44: transferred 2343 clusters with 7 clusters populated
# In stage 45: transferred 2267 clusters with 7 clusters populated
# In stage 46: transferred 2291 clusters with 7 clusters populated
# In stage 47: transferred 2294 clusters with 7 clusters populated
# In stage 48: transferred 2264 clusters with 7 clusters populated
# Tuning GSDMM model:   6%|████▍                                                                    | 9/150 [1:46:43<23:47:25, 607.42s/it]
# In stage 49: transferred 2234 clusters with 7 clusters populated
# End 2021-05-04 04:13:45.672396
# Duration 0:06:39.692186
# K = 50
# alpha = 0.01
# beta = 1.0
# n_iters = 100
# Start 2021-05-04 04:13:45.673374
# In stage 0: transferred 18451 clusters with 50 clusters populated
# In stage 1: transferred 15369 clusters with 50 clusters populated
# In stage 2: transferred 8549 clusters with 47 clusters populated
# In stage 3: transferred 5339 clusters with 29 clusters populated
# In stage 4: transferred 4252 clusters with 17 clusters populated
# In stage 5: transferred 3795 clusters with 14 clusters populated
# In stage 6: transferred 3563 clusters with 13 clusters populated
# In stage 7: transferred 3362 clusters with 9 clusters populated
# In stage 8: transferred 3292 clusters with 9 clusters populated
# In stage 9: transferred 3188 clusters with 9 clusters populated
# In stage 10: transferred 3125 clusters with 9 clusters populated
# In stage 11: transferred 3025 clusters with 9 clusters populated
# In stage 12: transferred 3051 clusters with 9 clusters populated
# In stage 13: transferred 3026 clusters with 10 clusters populated
# In stage 14: transferred 2937 clusters with 9 clusters populated
# In stage 15: transferred 2952 clusters with 9 clusters populated
# In stage 16: transferred 2905 clusters with 9 clusters populated
# In stage 17: transferred 2920 clusters with 9 clusters populated
# In stage 18: transferred 2941 clusters with 9 clusters populated
# In stage 19: transferred 2899 clusters with 9 clusters populated
# In stage 20: transferred 2882 clusters with 9 clusters populated
# In stage 21: transferred 2929 clusters with 9 clusters populated
# In stage 22: transferred 2818 clusters with 8 clusters populated
# In stage 23: transferred 2825 clusters with 8 clusters populated
# In stage 24: transferred 2826 clusters with 8 clusters populated
# In stage 25: transferred 2783 clusters with 8 clusters populated
# In stage 26: transferred 2778 clusters with 8 clusters populated
# In stage 27: transferred 2753 clusters with 7 clusters populated
# In stage 28: transferred 2750 clusters with 7 clusters populated
# In stage 29: transferred 2776 clusters with 7 clusters populated
# In stage 30: transferred 2721 clusters with 7 clusters populated
# In stage 31: transferred 2714 clusters with 7 clusters populated
# In stage 32: transferred 2586 clusters with 7 clusters populated
# In stage 33: transferred 2419 clusters with 7 clusters populated
# In stage 34: transferred 2268 clusters with 7 clusters populated
# In stage 35: transferred 2235 clusters with 7 clusters populated
# In stage 36: transferred 2295 clusters with 7 clusters populated
# In stage 37: transferred 2295 clusters with 8 clusters populated
# In stage 38: transferred 2258 clusters with 8 clusters populated
# ...
# In stage 92: transferred 2147 clusters with 15 clusters populated
# In stage 93: transferred 2141 clusters with 22 clusters populated
# In stage 94: transferred 2093 clusters with 18 clusters populated
# In stage 95: transferred 2147 clusters with 13 clusters populated
# In stage 96: transferred 2126 clusters with 15 clusters populated
# In stage 97: transferred 2105 clusters with 17 clusters populated
# In stage 98: transferred 2132 clusters with 19 clusters populated
# Tuning GSDMM model:  27%|███████████████████▏                                                    | 40/150 [7:04:31<19:36:39, 641.81s/it]
# In stage 99: transferred 2133 clusters with 19 clusters populated
# End 2021-05-04 09:31:33.403360
# Duration 0:13:14.953041
# K = 50
# alpha = 1.0
# beta = 0.01
# n_iters = 50
# Start 2021-05-04 09:31:33.404360
# In stage 0: transferred 17799 clusters with 50 clusters populated
# In stage 1: transferred 13752 clusters with 50 clusters populated
# In stage 2: transferred 10071 clusters with 50 clusters populated
# In stage 3: transferred 7982 clusters with 50 clusters populated
# In stage 4: transferred 6920 clusters with 50 clusters populated
# In stage 5: transferred 6170 clusters with 50 clusters populated
# In stage 6: transferred 5703 clusters with 50 clusters populated
# In stage 7: transferred 5579 clusters with 50 clusters populated
# In stage 8: transferred 5339 clusters with 50 clusters populated
# In stage 9: transferred 5257 clusters with 50 clusters populated
# In stage 10: transferred 5083 clusters with 50 clusters populated
# In stage 11: transferred 5046 clusters with 50 clusters populated
# In stage 12: transferred 4948 clusters with 50 clusters populated
# In stage 13: transferred 4915 clusters with 50 clusters populated
# In stage 14: transferred 4779 clusters with 50 clusters populated
# In stage 15: transferred 4598 clusters with 50 clusters populated
# In stage 16: transferred 4665 clusters with 50 clusters populated
# In stage 17: transferred 4664 clusters with 50 clusters populated
# In stage 18: transferred 4676 clusters with 50 clusters populated
# In stage 19: transferred 4609 clusters with 50 clusters populated
# In stage 20: transferred 4672 clusters with 50 clusters populated
# In stage 21: transferred 4587 clusters with 50 clusters populated
# In stage 22: transferred 4591 clusters with 50 clusters populated
# In stage 23: transferred 4565 clusters with 50 clusters populated
# In stage 24: transferred 4588 clusters with 50 clusters populated
# In stage 25: transferred 4555 clusters with 50 clusters populated
# In stage 26: transferred 4628 clusters with 50 clusters populated
# In stage 27: transferred 4537 clusters with 50 clusters populated
# In stage 28: transferred 4553 clusters with 50 clusters populated
# In stage 29: transferred 4547 clusters with 50 clusters populated
# In stage 30: transferred 4511 clusters with 50 clusters populated
# In stage 31: transferred 4483 clusters with 50 clusters populated
# In stage 32: transferred 4362 clusters with 50 clusters populated
# In stage 33: transferred 4428 clusters with 50 clusters populated
# In stage 34: transferred 4411 clusters with 50 clusters populated
# In stage 35: transferred 4353 clusters with 50 clusters populated
# In stage 36: transferred 4318 clusters with 50 clusters populated
# In stage 37: transferred 4437 clusters with 50 clusters populated
# In stage 38: transferred 4405 clusters with 50 clusters populated
# In stage 39: transferred 4317 clusters with 50 clusters populated
# In stage 40: transferred 4326 clusters with 50 clusters populated
# In stage 41: transferred 4317 clusters with 50 clusters populated
# In stage 42: transferred 4273 clusters with 50 clusters populated
# In stage 43: transferred 4317 clusters with 50 clusters populated
# In stage 44: transferred 4333 clusters with 50 clusters populated
# In stage 45: transferred 4307 clusters with 50 clusters populated
# In stage 46: transferred 4250 clusters with 50 clusters populated
# In stage 47: transferred 4369 clusters with 50 clusters populated
# In stage 48: transferred 4303 clusters with 50 clusters populated
# Tuning GSDMM model:  27%|███████████████████▋                                                    | 41/150 [7:11:17<17:17:27, 571.08s/it]
# In stage 49: transferred 4277 clusters with 50 clusters populated
# End 2021-05-04 09:38:19.445551
# Duration 0:06:46.041191
# K = 50
# alpha = 1.0
# beta = 0.01
# n_iters = 100
# Start 2021-05-04 09:38:19.447537
# In stage 0: transferred 17799 clusters with 50 clusters populated
# In stage 1: transferred 13752 clusters with 50 clusters populated
# In stage 2: transferred 10071 clusters with 50 clusters populated
# In stage 3: transferred 7982 clusters with 50 clusters populated
# In stage 4: transferred 6920 clusters with 50 clusters populated
# In stage 5: transferred 6170 clusters with 50 clusters populated
# In stage 6: transferred 5703 clusters with 50 clusters populated
# In stage 7: transferred 5579 clusters with 50 clusters populated
# In stage 8: transferred 5339 clusters with 50 clusters populated
# In stage 9: transferred 5257 clusters with 50 clusters populated
# In stage 10: transferred 5083 clusters with 50 clusters populated
# In stage 11: transferred 5046 clusters with 50 clusters populated
# In stage 12: transferred 4948 clusters with 50 clusters populated
# In stage 13: transferred 4915 clusters with 50 clusters populated
# In stage 14: transferred 4779 clusters with 50 clusters populated
# In stage 15: transferred 4598 clusters with 50 clusters populated
# In stage 16: transferred 4665 clusters with 50 clusters populated
# In stage 17: transferred 4664 clusters with 50 clusters populated
# In stage 18: transferred 4676 clusters with 50 clusters populated
# In stage 19: transferred 4609 clusters with 50 clusters populated
# In stage 20: transferred 4672 clusters with 50 clusters populated
# In stage 21: transferred 4587 clusters with 50 clusters populated
# In stage 22: transferred 4591 clusters with 50 clusters populated
# In stage 23: transferred 4565 clusters with 50 clusters populated
# In stage 24: transferred 4588 clusters with 50 clusters populated
# In stage 25: transferred 4555 clusters with 50 clusters populated
# In stage 26: transferred 4628 clusters with 50 clusters populated
# In stage 27: transferred 4537 clusters with 50 clusters populated
# In stage 28: transferred 4553 clusters with 50 clusters populated
# In stage 29: transferred 4547 clusters with 50 clusters populated
# In stage 30: transferred 4511 clusters with 50 clusters populated
# In stage 31: transferred 4483 clusters with 50 clusters populated
# In stage 32: transferred 4362 clusters with 50 clusters populated
# In stage 33: transferred 4428 clusters with 50 clusters populated
# In stage 34: transferred 4411 clusters with 50 clusters populated
# In stage 35: transferred 4353 clusters with 50 clusters populated
# In stage 36: transferred 4318 clusters with 50 clusters populated
# In stage 37: transferred 4437 clusters with 50 clusters populated
# In stage 38: transferred 4405 clusters with 50 clusters populated
# In stage 39: transferred 4317 clusters with 50 clusters populated
# In stage 40: transferred 4326 clusters with 50 clusters populated
# In stage 41: transferred 4317 clusters with 50 clusters populated
# In stage 42: transferred 4273 clusters with 50 clusters populated
# In stage 43: transferred 4317 clusters with 50 clusters populated
# In stage 44: transferred 4333 clusters with 50 clusters populated
# In stage 45: transferred 4307 clusters with 50 clusters populated
# In stage 46: transferred 4250 clusters with 50 clusters populated
# In stage 47: transferred 4369 clusters with 50 clusters populated
# In stage 48: transferred 4303 clusters with 50 clusters populated
# In stage 49: transferred 4277 clusters with 50 clusters populated
# In stage 50: transferred 4230 clusters with 50 clusters populated
# In stage 51: transferred 4344 clusters with 50 clusters populated
# In stage 52: transferred 4318 clusters with 50 clusters populated
# In stage 53: transferred 4278 clusters with 50 clusters populated
# In stage 54: transferred 4257 clusters with 50 clusters populated
# In stage 55: transferred 4254 clusters with 50 clusters populated
# In stage 56: transferred 4245 clusters with 50 clusters populated
# In stage 57: transferred 4165 clusters with 50 clusters populated
# In stage 58: transferred 4247 clusters with 50 clusters populated
# In stage 59: transferred 4272 clusters with 50 clusters populated
# In stage 60: transferred 4218 clusters with 50 clusters populated
# In stage 61: transferred 4310 clusters with 50 clusters populated
# In stage 62: transferred 4284 clusters with 50 clusters populated
# In stage 63: transferred 4257 clusters with 50 clusters populated
# In stage 64: transferred 4199 clusters with 50 clusters populated
# In stage 65: transferred 4170 clusters with 50 clusters populated
# In stage 66: transferred 4218 clusters with 50 clusters populated
# In stage 67: transferred 4285 clusters with 50 clusters populated
# In stage 68: transferred 4241 clusters with 50 clusters populated
# In stage 69: transferred 4200 clusters with 50 clusters populated
# In stage 70: transferred 4229 clusters with 50 clusters populated
# In stage 71: transferred 4204 clusters with 50 clusters populated
# In stage 72: transferred 4259 clusters with 50 clusters populated
# In stage 73: transferred 4222 clusters with 50 clusters populated
# In stage 74: transferred 4287 clusters with 50 clusters populated
# In stage 75: transferred 4296 clusters with 50 clusters populated
# In stage 76: transferred 4222 clusters with 50 clusters populated
# In stage 77: transferred 4215 clusters with 50 clusters populated
# In stage 78: transferred 4146 clusters with 50 clusters populated
# In stage 79: transferred 4180 clusters with 50 clusters populated
# In stage 80: transferred 4227 clusters with 50 clusters populated
# In stage 81: transferred 4183 clusters with 50 clusters populated
# In stage 82: transferred 4219 clusters with 50 clusters populated
# In stage 83: transferred 4216 clusters with 50 clusters populated
# In stage 84: transferred 4147 clusters with 50 clusters populated
# In stage 85: transferred 4172 clusters with 50 clusters populated
# In stage 86: transferred 4188 clusters with 50 clusters populated
# In stage 87: transferred 4230 clusters with 50 clusters populated
# In stage 88: transferred 4175 clusters with 50 clusters populated
# In stage 89: transferred 4193 clusters with 50 clusters populated
# In stage 90: transferred 4141 clusters with 50 clusters populated
# In stage 91: transferred 4207 clusters with 50 clusters populated
# In stage 92: transferred 4215 clusters with 50 clusters populated
# In stage 93: transferred 4319 clusters with 50 clusters populated
# In stage 94: transferred 4318 clusters with 50 clusters populated
# In stage 95: transferred 4161 clusters with 50 clusters populated
# In stage 96: transferred 4102 clusters with 50 clusters populated
# In stage 97: transferred 4171 clusters with 50 clusters populated
# In stage 98: transferred 4147 clusters with 50 clusters populated
# Tuning GSDMM model:  28%|████████████████████▏                                                   | 42/150 [7:24:59<19:23:06, 646.18s/it]
# In stage 99: transferred 4230 clusters with 50 clusters populated
# End 2021-05-04 09:52:00.843926
# Duration 0:13:41.396389
# K = 50
# alpha = 1.0
# beta = 0.25
# n_iters = 50
# Start 2021-05-04 09:52:00.845924
# In stage 0: transferred 18278 clusters with 50 clusters populated
# In stage 1: transferred 14842 clusters with 50 clusters populated
# In stage 2: transferred 9958 clusters with 50 clusters populated
# In stage 3: transferred 7111 clusters with 50 clusters populated
# In stage 4: transferred 5763 clusters with 47 clusters populated
# In stage 5: transferred 4946 clusters with 48 clusters populated
# In stage 6: transferred 4620 clusters with 47 clusters populated
# In stage 7: transferred 4453 clusters with 46 clusters populated
# In stage 8: transferred 4391 clusters with 43 clusters populated
# In stage 9: transferred 4236 clusters with 42 clusters populated
# In stage 10: transferred 4234 clusters with 38 clusters populated
# In stage 11: transferred 4258 clusters with 38 clusters populated
# In stage 12: transferred 4160 clusters with 37 clusters populated
# In stage 13: transferred 4045 clusters with 36 clusters populated
# In stage 14: transferred 3997 clusters with 39 clusters populated
# In stage 15: transferred 4025 clusters with 35 clusters populated
# In stage 16: transferred 4050 clusters with 37 clusters populated
# In stage 17: transferred 3998 clusters with 35 clusters populated
# In stage 18: transferred 3913 clusters with 35 clusters populated
# In stage 19: transferred 4065 clusters with 34 clusters populated
# In stage 20: transferred 3952 clusters with 37 clusters populated
# In stage 21: transferred 3959 clusters with 35 clusters populated
# In stage 22: transferred 3884 clusters with 34 clusters populated
# In stage 23: transferred 3961 clusters with 33 clusters populated
# In stage 24: transferred 3958 clusters with 33 clusters populated
# In stage 25: transferred 3917 clusters with 33 clusters populated
# In stage 26: transferred 3940 clusters with 33 clusters populated
# In stage 27: transferred 4003 clusters with 35 clusters populated
# In stage 28: transferred 3964 clusters with 34 clusters populated
# In stage 29: transferred 3961 clusters with 41 clusters populated
# In stage 30: transferred 3985 clusters with 37 clusters populated
# In stage 31: transferred 3911 clusters with 34 clusters populated
# In stage 32: transferred 3900 clusters with 35 clusters populated
# In stage 33: transferred 3870 clusters with 35 clusters populated
# In stage 34: transferred 3854 clusters with 41 clusters populated
# In stage 35: transferred 3781 clusters with 34 clusters populated
# In stage 36: transferred 3815 clusters with 36 clusters populated
# In stage 37: transferred 3858 clusters with 30 clusters populated
# In stage 38: transferred 3820 clusters with 31 clusters populated
# In stage 39: transferred 3885 clusters with 34 clusters populated
# In stage 40: transferred 3973 clusters with 35 clusters populated
# In stage 41: transferred 3796 clusters with 35 clusters populated
# In stage 42: transferred 3800 clusters with 32 clusters populated
# In stage 43: transferred 3740 clusters with 31 clusters populated
# In stage 44: transferred 3734 clusters with 31 clusters populated
# In stage 45: transferred 3796 clusters with 30 clusters populated
# In stage 46: transferred 3811 clusters with 30 clusters populated
# In stage 47: transferred 3731 clusters with 30 clusters populated
# In stage 48: transferred 3709 clusters with 36 clusters populated
# Tuning GSDMM model:  29%|████████████████████▋                                                   | 43/150 [7:31:49<17:06:28, 575.59s/it]
# In stage 49: transferred 3761 clusters with 30 clusters populated
# End 2021-05-04 09:58:51.736251
# Duration 0:06:50.890327
# K = 50
# alpha = 1.0
# beta = 0.25
# n_iters = 100
# Start 2021-05-04 09:58:51.736251
# In stage 0: transferred 18278 clusters with 50 clusters populated
# In stage 1: transferred 14842 clusters with 50 clusters populated
# In stage 2: transferred 9958 clusters with 50 clusters populated
# In stage 3: transferred 7111 clusters with 50 clusters populated
# In stage 4: transferred 5763 clusters with 47 clusters populated
# In stage 5: transferred 4946 clusters with 48 clusters populated
# In stage 6: transferred 4620 clusters with 47 clusters populated
# In stage 7: transferred 4453 clusters with 46 clusters populated
# In stage 8: transferred 4391 clusters with 43 clusters populated
# In stage 9: transferred 4236 clusters with 42 clusters populated
# In stage 10: transferred 4234 clusters with 38 clusters populated
# In stage 11: transferred 4258 clusters with 38 clusters populated
# In stage 12: transferred 4160 clusters with 37 clusters populated
# In stage 13: transferred 4045 clusters with 36 clusters populated
# In stage 14: transferred 3997 clusters with 39 clusters populated
# In stage 15: transferred 4025 clusters with 35 clusters populated
# In stage 16: transferred 4050 clusters with 37 clusters populated
# In stage 17: transferred 3998 clusters with 35 clusters populated

# %%
# np.vstack(
#     (
#         np.unique(gsdmm_cluster_labels, return_counts=True)[0],
#         np.unique(gsdmm_cluster_labels, return_counts=True)[1],
#     )
# ).T

# %% [markdown]
# ## Tuning hyperparameters

# %%
# # Plot the log-likelihood
# plt.figure(figsize=(12, 8))
# plt.plot(n_range, score_list, "-o", color="brown")
# plt.xlabel("Number of Components")
# plt.ylabel("Log-likelihood")
# plt.xticks(n_range)
# plt.title("Average log-likelihood of BGM models")
# plt.grid()

# %%
# i = 0
# silho_table = {"K": [], "alpha": [], "beta": [], "n_iters": [], "Silhouette": []}

# for K in k_range:
#     #     print('K =', K)
#     for alpha in alpha_range:
#         #         print('alpha =', alpha)
#         for beta in beta_range:
#             #             print('beta =', beta)
#             for n_iters in n_iter_range:
#                 #                 print('n_iters =', n_iters)
#                 #                 print("i =", i)
#                 silho_score = metrics.silhouette_score(title_embeddings, labels_list[i])
#                 silho_table["K"].append(K)
#                 silho_table["alpha"].append(alpha)
#                 silho_table["beta"].append(beta)
#                 silho_table["n_iters"].append(n_iters)
#                 silho_table["Silhouette"].append(silho_score)
#                 i += 1

# # pd.DataFrame(silho_table)

# %%
# Calculate Silhouette score
for idx, _ in tqdm(enumerate(model_list)):
    silho_score = metrics.silhouette_score(title_embeddings, labels_list[idx])
    model_result["Silhouette"].append(silho_score)

# %%
def get_average_score(models, docs):
    avg_score_list = []
    for model in models:
        score_list = []
        for doc in docs:
            score = model.score(doc)
            score_list.append(score)
#             print(score_list)
            avg_score = np.mean(score_list)
#             print(avg_score)
        avg_score_list.append(avg_score)
    return avg_score_list

# %%
# Create average score
avg_scores = get_average_score(model_list, title_docs)
# print(avg_scores)
model_result['Average Score'] = avg_scores

# %%
pd.DataFrame(model_result)
# model_result

# %%
# Save tuning results to file
pd.DataFrame(model_result).to_csv(
    OUTPUT_DIR + "job-title_gsdmm-tuning-results.csv", index=False
)

# %%
# Combine model sets
tuple_objects = (
    k_range,
    alpha_range,
    beta_range,
    model_list,
    duration_list,
    labels_list,
    model_result
)
len(tuple_objects), len(tuple_objects[0])

# %%
# Save tuple
pickle.dump(tuple_objects, open(OUTPUT_DIR + "title_gsdmm_tuning_results.pkl", "wb"))

# %%
# Select best model base on Silhouette score
best_index = np.argmax(model_result["Silhouette"])
# best_score = silho_table["Silhouette"][best_index]
best_n = len(np.unique(labels_list[best_index]))
best_model = model_list[best_index]
best_labels = labels_list[best_index]
best_params = [(key, value[best_index]) for key, value in model_result.items()]
best_index, best_n, best_params

# %%
# # indexes = len(silho_list) % (len(alpha_range)*len(beta_range)*len(n_iter_range))
# score_range = np.arange(len(silho_list))
# print(score_range)

# indexes = score_range % (len(alpha_range)*len(beta_range)*len(n_iter_range))
# print(indexes)

# print(score_range[indexes == 0])
# print(silho_list)
# print(np.asarray(silho_list)[np.where(np.asarray(indexes) == 0)])

# %%
# silho_df = pd.DataFrame(silho_table)
# # Plot the Silhouette score
# for b in beta_range:
#     plt.figure(figsize=(16, 5))
#     for ids, a in enumerate(alpha_range):
#         plot_df = silho_df.loc[silho_df["beta"] == b]
#         plot_df = plot_df.loc[plot_df['alpha'] == a]
#         plt.subplot(1, len(alpha_range), ids+1)
#         for n_iters in n_iter_range:
#             plt.plot(
#                 plot_df["K"].loc[plot_df['n_iters'] == n_iters],
#                 plot_df["Silhouette"].loc[plot_df['n_iters'] == n_iters],
#                 label=f"n_iters = {n_iters}",
#             )
#         plt.title(f"Alpha = {a} \n Beta = {b}")
#         plt.legend(loc="best")
#         plt.xlabel("Number of maximum usable clusters")
#         plt.xticks(k_range)
#         plt.ylabel("Silhouette score")
#         plt.grid()
#     plt.show()

# %%
pca_datapoint = np.load(OUTPUT_DIR + "pca_datapoints.npy")
tsne_datapoint = np.load(OUTPUT_DIR + "tsne_datapoints.npy")

# %%
plot_title = f"GSDMM visualization of job titles (number of components = {best_n})"
palette = sns.color_palette("hls", as_cmap=True)
colors = np.asarray(best_labels) / best_n

# Visualize clusters with PCA and t-SNE
visualize_cluster(
    plot_title,
    (12, 12),
    colors,
    palette,
    pca_datapoint,
    tsne_datapoint,
    None,
    pca=True,
    tsne=True,
    mds=False
)

# %% [markdown]
# ## Save cluster results to file

# %%
np.save(OUTPUT_DIR + "job-title_gsdmm-clusters.csv", best_labels)
